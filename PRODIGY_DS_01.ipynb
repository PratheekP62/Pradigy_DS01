# %%
#Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Reading data for total, male, and female populations
total_population_url = "C:\\Users\\Acer\\Downloads\\API_SP.POP.TOTL_DS2_en_csv_v2_6011311.csv"
male_population_url = "C:\\Users\\Acer\\Downloads\\API_SP.POP.TOTL.MA.IN_DS2_en_csv_v2_5996754.csv"
female_population_url = "C:\\Users\\Acer\\Downloads\\API_SP.POP.TOTL.FE.IN_DS2_en_csv_v2_5996755.csv"

# %%
df_total = pd.read_csv(total_population_url, skiprows=4, usecols=lambda x: x not in ['Unnamed: 67'])
df_male = pd.read_csv(male_population_url, skiprows=4, usecols=lambda x: x not in ['Unnamed: 67'])
df_female = pd.read_csv(female_population_url, skiprows=4, usecols=lambda x: x not in ['Unnamed: 67'])

# %%
df_total.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172712e+08  1.188807e+08  1.210511e+08  1.237333e+08  1.264378e+08
# std    3.695439e+08  3.740897e+08  3.808061e+08  3.895039e+08  3.982439e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291813e+08  1.320404e+08  1.348980e+08  1.378358e+08  1.408789e+08
# ...

# %%
df_male.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   5.866578e+07  5.946957e+07  6.056163e+07  6.191706e+07  6.328356e+07
# std    1.855425e+08  1.878102e+08  1.911964e+08  1.956043e+08  2.000331e+08
# min    1.258000e+03  1.389000e+03  1.540000e+03  1.702000e+03  1.873000e+03
# 25%    2.498010e+05  2.533402e+05  2.571170e+05  2.616788e+05  2.736948e+05
# 50%    1.865036e+06  1.930430e+06  1.979972e+06  2.012514e+06  2.039130e+06
# 75%    1.340071e+07  1.379332e+07  1.420430e+07  1.463027e+07  1.505867e+07
# max    1.514860e+09  1.535309e+09  1.562679e+09  1.596305e+09  1.630147e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   6.466583e+07  6.610485e+07  6.754250e+07  6.902276e+07  7.055933e+07
# ...

# %%
df_female.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   5.860540e+07  5.941115e+07  6.048946e+07  6.181622e+07  6.315427e+07
# std    1.840350e+08  1.863128e+08  1.896426e+08  1.939321e+08  1.982430e+08
# min    1.387000e+03  1.498000e+03  1.631000e+03  1.779000e+03  1.938000e+03
# 25%    2.660142e+05  2.706250e+05  2.755698e+05  2.808372e+05  2.864248e+05
# 50%    1.920326e+06  1.965698e+06  2.011768e+06  2.076098e+06  2.134238e+06
# 75%    1.330535e+07  1.369362e+07  1.409859e+07  1.449977e+07  1.490003e+07
# max    1.516615e+09  1.537113e+09  1.564171e+09  1.597124e+09  1.630295e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   6.451547e+07  6.593558e+07  6.735552e+07  6.881309e+07  7.031954e+07
# ...

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df_male.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df_female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df_total.shape
# Out:
# (266, 67)

# %%
df_male.shape
# Out:
# (266, 67)

# %%
df_female.shape
# Out:
# (266, 67)

# %%
df_total.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2018              float64
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# Length: 67, dtype: object

# %%
df_male.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2018              float64
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# Length: 67, dtype: object

# %%
df_female.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2018              float64
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# Length: 67, dtype: object

# %%
df_total.duplicated().sum()
# Out:
# 0

# %%
df_total.isna().sum().any()
# Out:
# True

# %%
df_total = df_total.fillna(method = "ffill")
df_total.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
df_total.isna().sum().any()
# Out:
# False

# %%
df_male.duplicated().sum()
# Out:
# 0

# %%
df_male.isna().sum().any()
# Out:
# True

# %%
df_male = df_male.fillna(method = "ffill")
df_male.head()
# Out:
#                   Country Name Country Code    Indicator Name  \
# 0                        Aruba          ABW  Population, male
# 1  Africa Eastern and Southern          AFE  Population, male
# 2                  Afghanistan          AFG  Population, male
# 3   Africa Western and Central          AFW  Population, male
# 4                       Angola          AGO  Population, male
#
#       Indicator Code        1960        1961        1962        1963  \
# 0  SP.POP.TOTL.MA.IN     26834.0     27431.0     27863.0     28256.0
# 1  SP.POP.TOTL.MA.IN  64839355.0  66562958.0  68378478.0  70254903.0
# 2  SP.POP.TOTL.MA.IN   4476521.0   4556369.0   4642166.0   4732954.0
# 3  SP.POP.TOTL.MA.IN  48453387.0  49463944.0  50516419.0  51622609.0
# 4  SP.POP.TOTL.MA.IN   2686966.0   2736939.0   2778711.0   2820354.0
#
#          1964        1965  ...         2013         2014         2015  \
# 0     28608.0     28906.0  ...      48927.0      49191.0      49430.0
# ...

# %%
df_male.isna().sum().any()
# Out:
# False

# %%
df_female.duplicated().sum()
# Out:
# 0

# %%
df_female.isna().sum().any()
# Out:
# True

# %%
df_female = df_female.fillna(method = "ffill")
df_female.head()
# Out:
#                   Country Name Country Code      Indicator Name  \
# 0                        Aruba          ABW  Population, female
# 1  Africa Eastern and Southern          AFE  Population, female
# 2                  Afghanistan          AFG  Population, female
# 3   Africa Western and Central          AFW  Population, female
# 4                       Angola          AGO  Population, female
#
#       Indicator Code        1960        1961        1962        1963  \
# 0  SP.POP.TOTL.FE.IN     27773.0     28380.0     28820.0     29218.0
# 1  SP.POP.TOTL.FE.IN  65853220.0  67606287.0  69457112.0  71375643.0
# 2  SP.POP.TOTL.FE.IN   4145945.0   4233771.0   4326881.0   4424511.0
# 3  SP.POP.TOTL.FE.IN  48802898.0  49850088.0  50928609.0  52044907.0
# 4  SP.POP.TOTL.FE.IN   2670229.0   2704394.0   2742689.0   2779473.0
#
#          1964        1965  ...         2013         2014         2015  \
# 0     29570.0     29875.0  ...      53953.0      54403.0      54828.0
# ...

# %%
df_female.isna().sum().any()
# Out:
# False

# %%
df_total['Country Name'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %%
#Choosing a country or region to visualize
country_to_visualize = 'World'

# %%
#Filtering data for the selected country or region
selected_country_data_total = df_total[df_total['Country Name'] == country_to_visualize]
selected_country_data_male = df_male[df_male['Country Name'] == country_to_visualize]
selected_country_data_female = df_female[df_female['Country Name'] == country_to_visualize]

# %%
#Plotting a bar chart for the distribution of male and female populations
years = selected_country_data_total.columns[4:]
plt.figure(figsize=(12, 6))
plt.bar(years, selected_country_data_male.iloc[0, 4:], label='Male', color='#008080', alpha=0.7)
plt.bar(years, selected_country_data_female.iloc[0, 4:], label='Female', bottom=selected_country_data_male.iloc[0, 4:], color='#FF1493', alpha=0.7)

plt.title(f'Population Distribution in {country_to_visualize} by Gender (1960-2022)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.xticks(rotation=90)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#Changing a country or region to visualize
country_to_visualize = 'Aruba'

# %%
#Filtering data for the selected country or region
selected_country_data_total = df_total[df_total['Country Name'] == country_to_visualize]
selected_country_data_male = df_male[df_male['Country Name'] == country_to_visualize]
selected_country_data_female = df_female[df_female['Country Name'] == country_to_visualize]

# %%
#Plotting a bar chart for the distribution of male and female populations
years = selected_country_data_total.columns[4:]
plt.figure(figsize=(12, 6))
plt.bar(years, selected_country_data_male.iloc[0, 4:], label='Male', color='#008080', alpha=0.7)
plt.bar(years, selected_country_data_female.iloc[0, 4:], label='Female', bottom=selected_country_data_male.iloc[0, 4:], color='#FF1493', alpha=0.7)

plt.title(f'Population Distribution in {country_to_visualize} by Gender (1960-2022)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.xticks(rotation=90)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Reading data for total, male, and female populations
total_population_url = "C:\\Users\\Acer\\Downloads\\API_SP.POP.TOTL_DS2_en_csv_v2_6011311.csv"
male_population_url = "C:\\Users\\Acer\\Downloads\\API_SP.POP.TOTL.MA.IN_DS2_en_csv_v2_5996754.csv"
female_population_url = "C:\\Users\\Acer\\Downloads\\API_SP.POP.TOTL.FE.IN_DS2_en_csv_v2_5996755.csv"
df_total = pd.read_csv(total_population_url, skiprows=4, usecols=lambda x: x not in ['Unnamed: 67'])
df_male = pd.read_csv(male_population_url, skiprows=4, usecols=lambda x: x not in ['Unnamed: 67'])
df_female = pd.read_csv(female_population_url, skiprows=4, usecols=lambda x: x not in ['Unnamed: 67'])

# %%
#Choosing a country or region to visualize
country_to_visualize = 'World'

# %%
#Filtering data for the selected country or region
selected_country_data_total = df_total[df_total['Country Name'] == country_to_visualize]
selected_country_data_male = df_male[df_male['Country Name'] == country_to_visualize]
selected_country_data_female = df_female[df_female['Country Name'] == country_to_visualize]
years = selected_country_data_total.columns[4:]
male_population = selected_country_data_male.iloc[0, 4:]
female_population = selected_country_data_female.iloc[0, 4:]

# %%
# Plotting a bar chart for the distribution of male and female populations
plt.figure(figsize=(12, 6))
plt.bar(years_numeric, male_population, width=bar_width, label='Male', color='#008080', alpha=0.7)
plt.bar([year + bar_width for year in years_numeric], female_population, width=bar_width, label='Female', color='#FF1493', alpha=0.7)

plt.title(f'Population Distribution in {country_to_visualize} by Gender (1960-2022)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.xticks([year + bar_width/2 for year in years_numeric], years_numeric, rotation=90)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
